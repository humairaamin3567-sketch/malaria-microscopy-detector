# %% [markdown]
# # 02 - Training (Transfer Learning)

# %% [markdown]
# Quick demo training using a small subset. Use `src/train.py` for full training.

# %%
# Quick test: import and run a small epoch (requires dataset)
from src.train import main
print('Use src/train.py from command line for full runs')
